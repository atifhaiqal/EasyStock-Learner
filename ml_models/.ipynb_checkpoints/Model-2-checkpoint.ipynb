# %%
import pandas as pd
import numpy as np
import yfinance as yf
import requests
import time

# %%
sp500_financials = pd.read_csv("constituents-financials.csv")
sp500_financials
# Out:
#     Symbol                 Name                                        Sector  \
# 0      MMM                   3M                      Industrial Conglomerates
# 1      AOS          A. O. Smith                             Building Products
# 2      ABT  Abbott Laboratories                         Health Care Equipment
# 3     ABBV               AbbVie                                 Biotechnology
# 4      ACN            Accenture                IT Consulting & Other Services
# ..     ...                  ...                                           ...
# 498    XYL           Xylem Inc.  Industrial Machinery & Supplies & Components
# 499    YUM          Yum! Brands                                   Restaurants
# 500   ZBRA   Zebra Technologies            Electronic Equipment & Instruments
# 501    ZBH        Zimmer Biomet                         Health Care Equipment
# 502    ZTS               Zoetis                               Pharmaceuticals
#
#       Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    152.20       21.286713          0.0199            7.15    75.652176
# 1     67.30       18.539946          0.0196            3.63    66.760000
# 2    127.93       16.744764          0.0202            7.64    99.710000
# 3    183.90       64.300700          0.0373            2.86   153.580000
# 4    384.95       32.294464          0.0170           11.92   278.690000
# ..      ...             ...             ...             ...          ...
# 498  124.04       35.643677          0.0118            3.48   112.020000
# 499  130.50       24.392525          0.0205            5.35   122.130000
# 500  391.94       53.397820             NaN            7.34   237.060000
# 501  109.48       20.893131          0.0087            5.24   100.670000
# 502  170.90       32.124058          0.0116            5.32   144.800000
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0          155.00  8.329418e+10  8.117000e+09     2.552062   17.855467
# 1           92.45  9.758165e+09  8.091000e+08     2.506078    5.091157
# 2          129.85  2.218895e+11  1.082500e+10     5.383446    5.575749
# 3          207.32  3.249770e+11  2.563000e+10     5.851963   53.882210
# 4          387.51  2.407785e+11  1.106591e+10     3.710195    8.508687
# ..            ...           ...           ...          ...         ...
# 498        146.08  3.013490e+10  1.689000e+09     3.577267    2.845411
# 499        143.20  3.641890e+10  2.608000e+09     5.042073         NaN
# 500        427.76  2.021626e+10  8.030000e+08     4.341981    5.905112
# 501        133.90  2.179462e+10  2.557400e+09     2.869412    1.765892
# 502        200.53  7.710410e+10  3.764000e+09     8.424835   14.744198
#
#                                            SEC Filings
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4    http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..                                                 ...
# 498  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 499  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 500  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [503 rows x 14 columns]

# %%
sp500_financials.info
# Out:
# <bound method DataFrame.info of     Symbol                 Name                                        Sector  \
# 0      MMM                   3M                      Industrial Conglomerates
# 1      AOS          A. O. Smith                             Building Products
# 2      ABT  Abbott Laboratories                         Health Care Equipment
# 3     ABBV               AbbVie                                 Biotechnology
# 4      ACN            Accenture                IT Consulting & Other Services
# ..     ...                  ...                                           ...
# 498    XYL           Xylem Inc.  Industrial Machinery & Supplies & Components
# 499    YUM          Yum! Brands                                   Restaurants
# 500   ZBRA   Zebra Technologies            Electronic Equipment & Instruments
# 501    ZBH        Zimmer Biomet                         Health Care Equipment
# 502    ZTS               Zoetis                               Pharmaceuticals
#
#       Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    152.20       21.286713          0.0199            7.15    75.652176
# 1     67.30       18.539946          0.0196            3.63    66.760000
# 2    127.93       16.744764          0.0202            7.64    99.710000
# 3    183.90       64.300700          0.0373            2.86   153.580000
# 4    384.95       32.294464          0.0170           11.92   278.690000
# ..      ...             ...             ...             ...          ...
# 498  124.04       35.643677          0.0118            3.48   112.020000
# 499  130.50       24.392525          0.0205            5.35   122.130000
# 500  391.94       53.397820             NaN            7.34   237.060000
# 501  109.48       20.893131          0.0087            5.24   100.670000
# 502  170.90       32.124058          0.0116            5.32   144.800000
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0          155.00  8.329418e+10  8.117000e+09     2.552062   17.855467
# 1           92.45  9.758165e+09  8.091000e+08     2.506078    5.091157
# 2          129.85  2.218895e+11  1.082500e+10     5.383446    5.575749
# 3          207.32  3.249770e+11  2.563000e+10     5.851963   53.882210
# 4          387.51  2.407785e+11  1.106591e+10     3.710195    8.508687
# ..            ...           ...           ...          ...         ...
# 498        146.08  3.013490e+10  1.689000e+09     3.577267    2.845411
# 499        143.20  3.641890e+10  2.608000e+09     5.042073         NaN
# 500        427.76  2.021626e+10  8.030000e+08     4.341981    5.905112
# 501        133.90  2.179462e+10  2.557400e+09     2.869412    1.765892
# 502        200.53  7.710410e+10  3.764000e+09     8.424835   14.744198
#
#                                            SEC Filings
# 0    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3    http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4    http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..                                                 ...
# 498  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 499  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 500  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [503 rows x 14 columns]>

# %%
sp500_financials = sp500_financials.drop(['SEC Filings'], axis=1)
sp500_financials
# Out:
#     Symbol                 Name                                        Sector  \
# 0      MMM                   3M                      Industrial Conglomerates
# 1      AOS          A. O. Smith                             Building Products
# 2      ABT  Abbott Laboratories                         Health Care Equipment
# 3     ABBV               AbbVie                                 Biotechnology
# 4      ACN            Accenture                IT Consulting & Other Services
# ..     ...                  ...                                           ...
# 498    XYL           Xylem Inc.  Industrial Machinery & Supplies & Components
# 499    YUM          Yum! Brands                                   Restaurants
# 500   ZBRA   Zebra Technologies            Electronic Equipment & Instruments
# 501    ZBH        Zimmer Biomet                         Health Care Equipment
# 502    ZTS               Zoetis                               Pharmaceuticals
#
#       Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    152.20       21.286713          0.0199            7.15    75.652176
# 1     67.30       18.539946          0.0196            3.63    66.760000
# 2    127.93       16.744764          0.0202            7.64    99.710000
# 3    183.90       64.300700          0.0373            2.86   153.580000
# 4    384.95       32.294464          0.0170           11.92   278.690000
# ..      ...             ...             ...             ...          ...
# 498  124.04       35.643677          0.0118            3.48   112.020000
# 499  130.50       24.392525          0.0205            5.35   122.130000
# 500  391.94       53.397820             NaN            7.34   237.060000
# 501  109.48       20.893131          0.0087            5.24   100.670000
# 502  170.90       32.124058          0.0116            5.32   144.800000
#
#      52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book
# 0          155.00  8.329418e+10  8.117000e+09     2.552062   17.855467
# 1           92.45  9.758165e+09  8.091000e+08     2.506078    5.091157
# 2          129.85  2.218895e+11  1.082500e+10     5.383446    5.575749
# 3          207.32  3.249770e+11  2.563000e+10     5.851963   53.882210
# 4          387.51  2.407785e+11  1.106591e+10     3.710195    8.508687
# ..            ...           ...           ...          ...         ...
# 498        146.08  3.013490e+10  1.689000e+09     3.577267    2.845411
# 499        143.20  3.641890e+10  2.608000e+09     5.042073         NaN
# 500        427.76  2.021626e+10  8.030000e+08     4.341981    5.905112
# 501        133.90  2.179462e+10  2.557400e+09     2.869412    1.765892
# 502        200.53  7.710410e+10  3.764000e+09     8.424835   14.744198
#
# [503 rows x 13 columns]

# %%
# import requests
# import pandas as pd
# import time

# # List of stock tickers
# tickers = [
#     "AAPL", "TSLA", "AMZN", "MSFT", "NVDA", "GOOGL", "META", "NFLX", "JPM", "V",
#     "BAC", "AMD", "PYPL", "DIS", "T", "PFE", "COST", "INTC", "KO", "TGT", "NKE",
#     "SPY", "BA", "BABA", "XOM", "WMT", "GE", "CSCO", "VZ", "JNJ", "CVX", "PLTR",
#     "SQ", "SHOP", "SBUX", "SOFI", "HOOD", "RBLX", "SNAP", "UBER", "FDX", "ABBV",
#     "ETSY", "MRNA", "LMT", "GM", "F", "RIVN", "LCID", "CCL", "DAL", "UAL",
#     "AAL", "TSM", "SONY", "ET", "NOK", "MRO", "COIN", "SIRI", "RIOT", "CPRX",
#     "VWO", "SPYG", "ROKU", "VIAC", "ATVI", "BIDU", "DOCU", "ZM", "PINS", "TLRY",
#     "WBA", "MGM", "NIO", "C", "GS", "WFC", "ADBE", "PEP", "UNH", "CARR", "FUBO",
#     "HCA", "TWTR", "BILI", "RKT"
# ]

# # Your API key (replace with your actual key)
# API_KEY = "OSrMm0u3iB8mz1iJMaK0XQno7DyqQKRw"

# # Base URL for API request
# BASE_URL = "https://financialmodelingprep.com/stable/grades-consensus?symbol={}&apikey={}"

# # List to store results
# data_list = []

# # Iterate through tickers and request data
# for ticker in tickers:
#     url = BASE_URL.format(ticker, API_KEY)
#     try:
#         response = requests.get(url)
#         if response.status_code == 200:
#             data = response.json()
#             if data:  # Ensure response is not empty
#                 consensus_rating = data[0].get("consensus", "N/A")  # Get consensus or "N/A"
#                 data_list.append({"Stock": ticker, "Consensus Rating": consensus_rating})
#             else:
#                 data_list.append({"Stock": ticker, "Consensus Rating": "N/A"})
#         else:
#             print(f"Error fetching data for {ticker}: {response.status_code}")
#             data_list.append({"Stock": ticker, "Consensus Rating": "N/A"})
#     except Exception as e:
#         print(f"Request failed for {ticker}: {e}")
#         data_list.append({"Stock": ticker, "Consensus Rating": "N/A"})
    
#     time.sleep(1)  # Add a delay to avoid hitting rate limits

# # Convert list to DataFrame
# df = pd.DataFrame(data_list)

# # Display the DataFrame
# print(df)

# # Save to CSV (optional)
# df.to_csv("stock_consensus_ratings.csv", index=False)
# Out:
#    Stock Consensus Rating
# 0   AAPL              Buy
# 1   TSLA              Buy
# 2   AMZN              Buy
# 3   MSFT              Buy
# 4   NVDA              Buy
# ..   ...              ...
# 82  FUBO              Buy
# 83   HCA              Buy
# 84  TWTR             Hold
# 85  BILI              Buy
# 86   RKT             Hold
#
# [87 rows x 2 columns]

# %%
# # Convert API data to DataFrame
# ratings_df = pd.DataFrame(data_list)

# # Merge with the original dataset
# ratings_df = ratings_df.rename(columns={'Stock': 'Symbol'})
# merged_df = sp500_financials.merge(ratings_df, on="Symbol", how="inner")  # Keep only matching rows

# # Display the final dataset
# print(merged_df)

# # Save to CSV (optional)
# merged_df.to_csv("merged_financials.csv", index=False)
# Out:
#    Symbol                       Name  \
# 0    ABBV                     AbbVie
# 1    ADBE                 Adobe Inc.
# 2     AMD     Advanced Micro Devices
# 3   GOOGL    Alphabet Inc. (Class A)
# 4    AMZN                     Amazon
# 5    AAPL                 Apple Inc.
# 6       T                       AT&T
# 7     BAC            Bank of America
# 8      BA                     Boeing
# 9     CCL                   Carnival
# 10   CARR             Carrier Global
# 11    CVX        Chevron Corporation
# 12   CSCO                      Cisco
# 13      C                  Citigroup
# 14     KO    Coca-Cola Company (The)
# 15   COST                     Costco
# 16    DAL            Delta Air Lines
# 17    XOM                 ExxonMobil
# 18    FDX                      FedEx
# 19      F         Ford Motor Company
# 20     GE               GE Aerospace
# 21     GM             General Motors
# 22     GS              Goldman Sachs
# 23    HCA             HCA Healthcare
# 24   INTC                      Intel
# 25    JNJ          Johnson & Johnson
# 26    JPM             JPMorgan Chase
# 27    LMT            Lockheed Martin
# 28    MRO               Marathon Oil
# 29   META             Meta Platforms
# 30    MGM                MGM Resorts
# 31   MSFT                  Microsoft
# 32   MRNA                    Moderna
# 33   NFLX                    Netflix
# 34    NKE                 Nike, Inc.
# 35   NVDA                     Nvidia
# 36   PLTR      Palantir Technologies
# 37   PYPL                     PayPal
# 38    PEP                    PepsiCo
# 39    PFE                     Pfizer
# 40   SBUX                  Starbucks
# 41    TGT         Target Corporation
# 42   TSLA                Tesla, Inc.
# 43   UBER                       Uber
# 44    UAL   United Airlines Holdings
# 45    UNH         UnitedHealth Group
# 46     VZ                    Verizon
# 47      V                  Visa Inc.
# 48    WBA   Walgreens Boots Alliance
# 49    WMT                    Walmart
# 50    DIS  Walt Disney Company (The)
# 51    WFC                Wells Fargo
#
#                                         Sector   Price  Price/Earnings  \
# 0                                Biotechnology  183.90       64.300700
# 1                         Application Software  437.45       35.421050
# 2                               Semiconductors  115.95      105.409090
# 3                 Interactive Media & Services  204.02       27.094290
# 4                             Broadline Retail  237.68       50.249470
# 5   Technology Hardware, Storage & Peripherals  236.00       37.760000
# 6        Integrated Telecommunication Services   23.73       16.142857
# 7                            Diversified Banks   46.30       14.423676
# 10  3.318000e+09     2.386601    3.994867              Buy
# 11  3.894300e+10     1.453950    1.716426              Buy
# 12  1.375200e+10     4.555935    5.340148              Buy
# 13           NaN     2.217049    0.799062              Buy
# 14  1.483100e+10     5.950795   10.316918              Buy
# 15  1.152200e+10     1.709423   18.381481              Buy
# 16  8.415000e+09     0.719785    3.160441              Buy
# 17  7.153800e+10     1.400655    1.748102              Buy
# 18  1.088500e+10     0.728319    2.346038              Buy
# 19  9.360000e+09     0.219220    0.904036              Buy
# 20  8.935000e+09     3.124542   11.673262              Buy
# 21  1.837100e+10     0.269554    0.766988              Buy
# 22           NaN     4.058910    1.954757              Buy
# 23  1.374700e+10     1.200287         NaN              Buy
# 24  1.043900e+10     1.550904    0.841162             Hold
# 25  3.005200e+10     4.196929    5.220629              Buy
# 26           NaN     4.611826    2.321320              Buy
# 27  1.022600e+10     1.528466   15.174709              Buy
# 28           NaN          NaN         NaN              Buy
# 29  7.920900e+10    11.141612   10.572515              Buy
# 30  2.556988e+09     0.596114    3.167371              Buy
# 31  1.365520e+11    12.138745   11.492731              Buy
# 32 -2.362000e+09     2.985539    1.272475             Hold
# 33  9.976899e+09    11.115886   18.376385              Buy
# 34  7.201000e+09     2.316641    8.009583              Buy
# 35  6.118400e+10    31.697422   68.847480              Buy
# 36  3.977070e+08    71.009026   41.619576             Hold
# 37  6.121000e+09     2.854598    4.417074              Buy
# 38  1.691300e+10     2.267252   10.635941              Buy
# 39  1.836600e+10     2.531176    1.628192             Hold
# 40  6.700000e+09     3.422607         NaN              Buy
# 41  9.231000e+09     0.588928    4.740153              Buy
# 42  1.324400e+10    13.395820   18.554527              Buy
# 43  3.445000e+09     3.355183    9.517368              Buy
# 44  7.483000e+09     0.621642    3.043216              Buy
# 45  3.503500e+10     1.274643    5.296668              Buy
# 46  4.842900e+10     1.235258    1.721440              Buy
# 47  2.497300e+10    18.435755   21.605562              Buy
# 48  2.884000e+09     0.060163    0.850360             Hold
# 49  4.077900e+10     1.191657    9.427585              Buy
# 50  1.675100e+10     2.278556    2.040463              Buy
# 51           NaN     3.328856    1.601040              Buy

# %%
import finnhub
finnhub_client = finnhub.Client(api_key="ctkp081r01qn6d7j5lt0ctkp081r01qn6d7j5ltg")

# %%
symbols = sp500_financials['Symbol']

# set a new pandas dataframe for the recommendations 
recommendation = pd.DataFrame(symbols)
recommendation[['Consensus', 'Consensus Score']] = None

recommendation
# Out:
#     Symbol Consensus Consensus Score
# 0      MMM      None            None
# 1      AOS      None            None
# 2      ABT      None            None
# 3     ABBV      None            None
# 4      ACN      None            None
# ..     ...       ...             ...
# 498    XYL      None            None
# 499    YUM      None            None
# 500   ZBRA      None            None
# 501    ZBH      None            None
# 502    ZTS      None            None
#
# [503 rows x 3 columns]

# %%
def calculate_consensus(ratings):
    weights = {'strongBuy': 5, 'buy': 4, 'hold': 3, 'sell': 2, 'strongSell': 1}
    
    total_weighted_score = 0
    total_ratings = 0
    for key, weight in weights.items():
        total_weighted_score += ratings[key] * weight
        total_ratings += ratings[key]
    
    if total_ratings == 0:
        return None  # Avoid division by zero

    consensus_score = total_weighted_score / total_ratings

    # Classify consensus
    if consensus_score >= 4.5:
        consensus_label = "Strong Buy"
    elif consensus_score >= 3.5:
        consensus_label = "Buy"
    elif consensus_score >= 2.5:
        consensus_label = "Hold"
    elif consensus_score >= 1.5:
        consensus_label = "Sell"
    else:
        consensus_label = "Strong Sell"

    return consensus_score, consensus_label

# %%
ratings = finnhub_client.recommendation_trends('AAPL')
consensus_score, consensus_label = calculate_consensus(ratings[0])

print(f"Consensus Score: {consensus_score:.2f}")
print(f"Consensus Rating: {consensus_label}")
# Out:
# Consensus Score: 3.81
# Consensus Rating: Buy

# %%
for s in symbols:
    try: 
        ratings = finnhub_client.recommendation_trends(s)

        if ratings:
            consensus_score, consensus_label = calculate_consensus(ratings[0])

            recommendation.loc[recommendation['Symbol'] == s, 'Consensus'] = consensus_label  
            recommendation.loc[recommendation['Symbol'] == s, 'Consensus Score'] = consensus_score
        else:
            print(f"Warning: No ratings available for {s}")
    except ReadTimeout:  # Handle timeout exceptions
        print(f"Timeout error encountered for {s}. Retrying...")
        time.sleep(5)  # Add a small delay before retrying the current symbol
        continue
        
    except finnhub.FinnhubAPIException as e: 
        if e.status_code == 429:
            print(f"API limit reached. Exiting loop.")
            break  # Exit the loop if the API limit is reached
        else:
            print(f"Error: Unable to pull data for {s} - {e}")
            continue  # Continue with the next iteration if it's another error
            
    except Exception as e:  # Handle any other exceptions
        print(f"An unexpected error occurred for {s}: {e}")
        continue  # Continue with the next symbol
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /opt/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /opt/anaconda3/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     707 try:
# --> 708     return self._sock.recv_into(b)
#     709 except timeout:
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1103 if buffer is not None:
# -> 1104     return self._sslobj.read(len, buffer)
#    1105 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.finnhub.io', port=443): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[196], line 3
#       1 for s in symbols:
#       2     try:
# ----> 3         ratings = finnhub_client.recommendation_trends(s)
#       5         if ratings:
#       6             consensus_score, consensus_label = calculate_consensus(ratings[0])
#
# File /opt/anaconda3/lib/python3.12/site-packages/finnhub/client.py:127, in Client.recommendation_trends(self, symbol)
#     126 def recommendation_trends(self, symbol):
# --> 127     return self._get("/stock/recommendation", params={"symbol": symbol})
#
# File /opt/anaconda3/lib/python3.12/site-packages/finnhub/client.py:71, in Client._get(self, path, **kwargs)
#      70 def _get(self, path, **kwargs):
# ---> 71     return self._request("get", path, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/finnhub/client.py:40, in Client._request(self, method, path, **kwargs)
#      37 kwargs["timeout"] = kwargs.get("timeout", self.DEFAULT_TIMEOUT)
#      38 kwargs["params"] = self._format_params(kwargs.get("params", {}))
# ---> 40 response = getattr(self._session, method)(uri, **kwargs)
#      41 return self._handle_response(response)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:635, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     633     raise SSLError(e, request=request)
#     634 elif isinstance(e, ReadTimeoutError):
# --> 635     raise ReadTimeout(e, request=request)
#     636 elif isinstance(e, _InvalidHeader):
#     637     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.finnhub.io', port=443): Read timed out. (read timeout=10)

# %%
recommendation['Consensus'].isna().sum()
# Out:
# 239

# %%
recommendation.to_csv('recommendation2.csv')
