# %% [markdown]
# # OIB Data Preprocessing
# Processing the open investment bank dataset to ease the process of data visualization.
# In the final application of the app, this will not be needed as the data used will be from APIs

# %% [markdown]
# ### Importing data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/Open_Investment_Data_2020-2024.csv")
df.head()
# Out:
#        Action Transaction Date      Time Ticker                       Name  \
# 0     Deposit       2020-04-30  17:20:49    NaN                        NaN
# 1  Market buy       2020-04-30  17:21:18   PBCT  People's United Financial
# 2     Deposit       2020-05-04  10:43:01    NaN                        NaN
# 3  Market buy       2020-05-04  10:43:01     NG              National Grid
# 4  Market buy       2020-05-04  15:39:01      T                       AT&T
#
#    No. of shares  Price / share Currency (Price / share) Exchange rate  \
# 0            NaN            NaN                      NaN           NaN
# 1           50.0          12.76                      USD       1.25847
# 2            NaN            NaN                      NaN           NaN
# 3            1.0         929.80                      GBX           100
# 4           15.0          29.34                      USD       1.24252
#
#    Result of Sell  ... Stamp duty reserve tax  \
# ...

# %% [markdown]
# ## Dropping un-wanted columns

# %%
df.drop(['Notes', 'ID', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'], axis=1, inplace=True)
df.head()
# Out:
#        Action Transaction Date      Time Ticker                       Name  \
# 0     Deposit       2020-04-30  17:20:49    NaN                        NaN
# 1  Market buy       2020-04-30  17:21:18   PBCT  People's United Financial
# 2     Deposit       2020-05-04  10:43:01    NaN                        NaN
# 3  Market buy       2020-05-04  10:43:01     NG              National Grid
# 4  Market buy       2020-05-04  15:39:01      T                       AT&T
#
#    No. of shares  Price / share Currency (Price / share) Exchange rate  \
# 0            NaN            NaN                      NaN           NaN
# 1           50.0          12.76                      USD       1.25847
# 2            NaN            NaN                      NaN           NaN
# 3            1.0         929.80                      GBX           100
# 4           15.0          29.34                      USD       1.24252
#
#    Result of Sell Currency (Result)  Total (GBP) Currency (Total)  Total USD  \
# ...

# %% [markdown]
# ### Merging all dividens into 1 catergory

# %%
df['Action'].describe()
# Out:
# count           3298
# unique            14
# top       Market buy
# freq            1365
# Name: Action, dtype: object

# %%
df['Action'] = df['Action'].replace(r'(?i)^dividend.*', 'Dividend', regex=True)

# %%
df['Action'].describe()
# Out:
# count           3298
# unique             7
# top       Market buy
# freq            1365
# Name: Action, dtype: object

# %% [markdown]
# ### Create new column called share/price (GBP)

# %%
df['Exchange rate'] = pd.to_numeric(df['Exchange rate'], errors='coerce')

df['Price / Share (GBP)'] = df['Price / share'] / df['Exchange rate']

# %%
df.head()
# Out:
#        Action Transaction Date      Time Ticker                       Name  \
# 0     Deposit       2020-04-30  17:20:49    NaN                        NaN
# 1  Market buy       2020-04-30  17:21:18   PBCT  People's United Financial
# 2     Deposit       2020-05-04  10:43:01    NaN                        NaN
# 3  Market buy       2020-05-04  10:43:01     NG              National Grid
# 4  Market buy       2020-05-04  15:39:01      T                       AT&T
#
#    No. of shares  Price / share Currency (Price / share)  Exchange rate  \
# 0            NaN            NaN                      NaN            NaN
# 1           50.0          12.76                      USD        1.25847
# 2            NaN            NaN                      NaN            NaN
# 3            1.0         929.80                      GBX      100.00000
# 4           15.0          29.34                      USD        1.24252
#
#    Result of Sell  ... Total (GBP)  Currency (Total) Total USD  \
# ...

# %%
df.to_csv("../data/OID-Dataset.csv")
