# %% [markdown]
# # Developer Notebook
# A notebook for developing functions in the main project

# %% [markdown]
# ## Imports

# %%
from transformers import pipeline
import datetime
import pandas as pd
import numpy as np
import plotly.express as px

from services.alpaca_api_client import Alpaca_APIClient, get_alpaca_client
from config.api_settings import Alpaca_APIConfig

# %% [markdown]
# ## Alpaca News Sentiment Analysis Function for a list of tickers

# %%
alpaca_api = get_alpaca_client(Alpaca_APIConfig.get_alpaca_api_key, Alpaca_APIConfig.get_alpaca_secret_key)
pipe = pipeline("text-classification", model="ProsusAI/finbert")
# Out:
# Device set to use mps:0

# %%
# Function to extract titles
def extract_titles(news_list):
    return [news['headline'] for news in news_list]

# %%
tickers = ['AAPL', 'NVDA', 'GOOGL']

dt_start = datetime.datetime(2024, 1, 3, 0, 0, 0)
dt_end = datetime.datetime(2025, 3, 3, 0, 0, 0)
combined_df = pd.DataFrame()
aggregated_sentiment_list = []

for ticker in tickers:
    alpaca_news = alpaca_api.get_news(ticker, alpaca_api.get_alpaca_datetime(dt_start), alpaca_api.get_alpaca_datetime(dt_end), limit=20)

    if alpaca_news is not None:
        news = alpaca_news
    else:
        news = []

    # Example news sentiment outputs
    titles = extract_titles(news)
    news_sentiments = pipe(titles) if titles else []

    # Count the occurrences of each sentiment label
    sentiment_counts = {'positive': 0, 'neutral': 0, 'negative': 0}
    for sentiment in news_sentiments: # pyright: ignore
        sentiment_counts[sentiment['label']] += 1 # pyright: ignore

    list_items = list(sentiment_counts.items())
    df = pd.DataFrame(list_items, columns=['Sentiment', 'Count']) # pyright: ignore

    df['ticker'] = ticker # Add column to identify ticker
    combined_df = pd.concat([combined_df, df])

    # Mapping sentiment labels to numerical values
    sentiment_map = {'positive': 1, 'neutral': 0, 'negative': -1}

    # Weighted average of sentiment scores
    weighted_scores = np.array([sentiment_map[item['label']] * item['score'] for item in news_sentiments]) # pyright: ignore
    average_score = np.sum(weighted_scores) / np.sum([item['score'] for item in news_sentiments]) # pyright: ignore

    # Determine the aggregated sentiment label
    aggregated_sentiment = "positive" if average_score > 0 else "negative" if average_score < 0 else "neutral"

    aggregated_sentiment_list.append((ticker, aggregated_sentiment))

aggregated_sentiment_df = pd.DataFrame(aggregated_sentiment_list, columns=['ticker','average_sentiment'])
combined_df = combined_df.reset_index(drop=True)
combined_df
# Out:
#   Sentiment  Count ticker
# 0  positive      2   AAPL
# 1   neutral     10   AAPL
# 2  negative      8   AAPL
# 3  positive      3   NVDA
# 4   neutral      9   NVDA
# 5  negative      8   NVDA
# 6  positive      5  GOOGL
# 7   neutral      8  GOOGL
# 8  negative      7  GOOGL

# %%
aggregated_sentiment_df
# Out:
#   ticker average_sentiment
# 0   AAPL          negative
# 1   NVDA          negative
# 2  GOOGL          negative

# %%
# Custom color palette
color_map = {
    'positive': 'green',  
    'neutral': 'yellow',   
    'negative': 'red'   
}

fig = px.sunburst(
    combined_df, 
    names='ticker',
    path=['ticker', 'Sentiment'], 
    values='Count',
    color='Sentiment',  # Assign colors based on Sentiment
    color_discrete_map=color_map  # Custom color map
)

fig.show()

# %% [markdown]
# ## Increase/Decrese over period

# %%
from services.finnhub_api_client import Finnhub_APIClient, get_finnhub_client

FINNHUB_API_KEY = 'ctkp081r01qn6d7j5lt0ctkp081r01qn6d7j5ltg'
finnhub_client = get_finnhub_client(FINNHUB_API_KEY)
# Out:
# 2025-03-09 15:38:45.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 15:38:45.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 15:38:45.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 15:38:45.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 15:38:45.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
metrics = finnhub_client.get_company_basic_financials(ticker, 'all')
metrics
# Out:
# {'metric': {'10DayAverageTradingVolume': 36.81216,
#   '13WeekPriceReturnDaily': 1.382,
#   '26WeekPriceReturnDaily': 7.4669,
#   '3MonthADReturnStd': 33.14123,
#   '3MonthAverageTradingVolume': 29.84499,
#   '52WeekHigh': 207.05,
#   '52WeekHighDate': '2025-02-04',
#   '52WeekLow': 130.85,
#   '52WeekLowDate': '2024-03-06',
#   '52WeekPriceReturnDaily': 32.3135,
#   '5DayPriceReturnDaily': 4.1016,
#   'assetTurnoverAnnual': 0.7774,
#   'assetTurnoverTTM': 0.8223,
#   'beta': 0.9915743,
#   'bookValuePerShareAnnual': 26.6222,
#   'bookValuePerShareQuarterly': 26.6222,
#   'bookValueShareGrowth5Y': 12.72,
#   'capexCagr5Y': 17.41,
#   'cashFlowPerShareAnnual': 5.9589,
#   'cashFlowPerShareQuarterly': 5.9589,
#   'cashFlowPerShareTTM': 6.35252,
#   'cashPerSharePerShareAnnual': 7.8337,
#   'cashPerSharePerShareQuarterly': 7.8337,
#   'currentDividendYieldTTM': None,
#   'currentEv/freeCashFlowAnnual': 29.1122,
#   'currentEv/freeCashFlowTTM': 29.1122,
#   'currentRatioAnnual': 1.8369,
#   'currentRatioQuarterly': 1.8369,
#   'dividendPerShareAnnual': 0.5969,
#   'dividendPerShareTTM': None,
#   'dividendYieldIndicatedAnnual': 0.46417174,
#   'ebitdPerShareAnnual': 9.6776,
#   'ebitdPerShareTTM': 10.1744,
#   'ebitdaCagr5Y': 23.41,
#   'ebitdaInterimCagr5Y': 23.8,
#   'enterpriseValue': 2118318.5,
#   'epsAnnual': 7.5203,
#   'epsBasicExclExtraItemsAnnual': 7.5203,
#   'epsBasicExclExtraItemsTTM': 7.9056,
#   'epsExclExtraItemsAnnual': 7.5203,
#   'epsExclExtraItemsTTM': 7.9056,
#   'epsGrowth3Y': 10.26,
#   'epsGrowth5Y': 25.06,
#   'epsGrowthQuarterlyYoy': 22.36,
#   'epsGrowthTTMYoy': 36.18,
#   'epsInclExtraItemsAnnual': 7.5203,
#   'epsInclExtraItemsTTM': 7.9056,
#   'epsNormalizedAnnual': 7.5203,
#   'epsTTM': 7.9056,
#   'focfCagr5Y': 18.63,
#   'grossMargin5Y': 56.21,
#   'grossMarginAnnual': 58.2,
#   'grossMarginTTM': 58.24,
#   'inventoryTurnoverAnnual': 65.7307,
#   'inventoryTurnoverTTM': 42.6553,
#   'longTermDebt/equityAnnual': 0.0335,
#   'longTermDebt/equityQuarterly': 0.0335,
#   'marketCapitalization': 2129667.5,
#   'monthToDatePriceReturnDaily': 2.1024,
#   'netIncomeEmployeeAnnual': 0.5523,
#   'netIncomeEmployeeTTM': 0.5523,
#   'netInterestCoverageAnnual': 84.046,
#   'netInterestCoverageTTM': 16.1988,
#   'netMarginGrowth5Y': 6.15,
#   'netProfitMargin5Y': 25.08,
#   'netProfitMarginAnnual': 28.6,
#   'netProfitMarginTTM': 28.6,
#   'operatingMargin5Y': 27.83,
#   'operatingMarginAnnual': 32.11,
#   'operatingMarginTTM': 32.11,
#   'payoutRatioAnnual': 7.35,
#   'payoutRatioTTM': None,
#   'pbAnnual': 7.1475,
#   'pbQuarterly': 7.1475,
#   'pcfShareAnnual': 16.9967,
#   'pcfShareTTM': 16.9967,
#   'peAnnual': 21.2716,
#   'peBasicExclExtraTTM': 21.2716,
#   'peExclExtraAnnual': 29.99239,
#   'peExclExtraTTM': 21.2716,
#   'peInclExtraTTM': 21.2716,
#   'peNormalizedAnnual': 21.2716,
#   'peTTM': 21.2716,
#   'pfcfShareAnnual': 29.2681,
#   'pfcfShareTTM': 29.2681,
#   'pretaxMargin5Y': 29.78,
#   'pretaxMarginAnnual': 34.23,
#   'pretaxMarginTTM': 34.23,
#   'priceRelativeToS&P50013Week': 5.9726,
#   'priceRelativeToS&P50026Week': 4.3201,
#   'priceRelativeToS&P5004Week': -2.0576,
#   'priceRelativeToS&P50052Week': 19.3326,
#   'priceRelativeToS&P500Ytd': -6.4228,
#   'psAnnual': 6.0845,
#   'psTTM': 6.0845,
#   'ptbvAnnual': 4.5068,
#   'ptbvQuarterly': 6.2217,
#   'quickRatioAnnual': 1.8369,
#   'quickRatioQuarterly': 1.8369,
#   'receivablesTurnoverAnnual': 6.9791,
#   'receivablesTurnoverTTM': 6.9791,
#   'revenueEmployeeAnnual': 1.9309,
#   'revenueEmployeeTTM': 1.9309,
#   'revenueGrowth3Y': 10.75,
#   'revenueGrowth5Y': 16.68,
#   'revenueGrowthQuarterlyYoy': 11.77,
#   'revenueGrowthTTMYoy': 13.87,
#   'revenuePerShareAnnual': 26.2914,
#   'revenuePerShareTTM': 26.4944,
#   'revenueShareGrowth5Y': 17.81,
#   'roa5Y': 18.15,
#   'roaRfy': 22.24,
#   'roaTTM': 23.52,
#   'roe5Y': 25.71,
#   'roeRfy': 30.8,
#   'roeTTM': 32.48,
#   'roi5Y': 24.38,
#   'roiAnnual': 29.56,
#   'roiTTM': 31.11,
#   'tangibleBookValuePerShareAnnual': 19.7727,
#   'tangibleBookValuePerShareQuarterly': 21.6385,
#   'tbvCagr5Y': 11.14,
#   'totalDebt/totalEquityAnnual': 0.0417,
#   'totalDebt/totalEquityQuarterly': 0.0373,
#   'yearToDatePriceReturnDaily': -8.1564},
#  'metricType': 'all',
#  'series': {'annual': {'bookValue': [{'period': '2024-12-31', 'v': 325084},
#     {'period': '2023-12-31', 'v': 283379},
#     {'period': '2022-12-31', 'v': 256144},
#     {'period': '2021-12-31', 'v': 251635},
#     {'period': '2020-12-31', 'v': 222544},
#     {'period': '2019-12-31', 'v': 201442},
#     {'period': '2018-12-31', 'v': 177628},
#     {'period': '2017-12-31', 'v': 152502},
#    'ebitPerShare': [{'period': '2024-12-31', 'v': 8.4421},
#     {'period': '2023-12-31', 'v': 6.674},
#     {'period': '2022-12-31', 'v': 5.6875},
#     {'period': '2021-12-31', 'v': 5.8077},
#     {'period': '2020-12-31', 'v': 3.0002},
#     {'period': '2019-12-31', 'v': 2.4501},
#     {'period': '2018-12-31', 'v': 1.9568},
#     {'period': '2017-12-31', 'v': 1.8603},
#     {'period': '2016-12-31', 'v': 1.6971},
#     {'period': '2015-12-31', 'v': 1.397},
#     {'period': '2014-12-31', 'v': 1.2005},
#     {'period': '2013-12-31', 'v': 1.0451},
#     {'period': '2012-12-31', 'v': 1.0408},
#     {'period': '2011-12-31', 'v': 0.8887},
#     {'period': '2010-12-31', 'v': 0.8029},
#     {'period': '2009-12-31', 'v': 0.6506},
#     {'period': '2008-12-31', 'v': 0.436},
#     {'period': '2007-12-31', 'v': 0.402},
#     {'period': '2006-12-31', 'v': 0.2867},
#     {'period': '2005-12-31', 'v': 0.1728},
#     {'period': '2004-12-31', 'v': 0.0587},
#     {'period': '2003-12-31', 'v': 0.0334},
#     {'period': '2002-12-31', 'v': 0.0211},
#     {'period': '2001-12-31', 'v': 0.0015},
#     {'period': '2000-12-31', 'v': -0.0055},
#     {'period': '1999-12-31', 'v': -0.0038}],
#    'eps': [{'period': '2024-12-31', 'v': 7.5203},
#     {'period': '2023-12-31', 'v': 5.8428},
#     {'period': '2022-12-31', 'v': 4.5575},
#     {'period': '2021-12-31', 'v': 5.6099},
#     {'period': '2020-12-31', 'v': 2.9307},
#     {'period': '2019-12-31', 'v': 2.4581},
#     {'period': '2018-12-31', 'v': 2.1852},
#     {'period': '2017-12-31', 'v': 0.8998},
#     {'period': '2016-12-31', 'v': 1.3939},
#     {'period': '2015-12-31', 'v': 1.1796},
#     {'period': '2014-12-31', 'v': 1.0287},
#     {'period': '2013-12-31', 'v': 0.8639},
#     {'period': '2012-12-31', 'v': 0.8078},
#     {'period': '2011-12-31', 'v': 0.7439},
#     {'period': '2010-12-31', 'v': 0.6578},
#     {'period': '2009-12-31', 'v': 0.5103},
#     {'period': '2008-12-31', 'v': 0.3328},
#     {'period': '2007-12-31', 'v': 0.3324},
#     {'period': '2006-12-31', 'v': 0.2485},
#     {'period': '2005-12-31', 'v': 0.1255},
#     {'period': '2004-12-31', 'v': 0.0366},
#     {'period': '2003-12-31', 'v': 0.0103},
#     {'period': '2002-12-31', 'v': 0.0113},
#     {'period': '2001-12-31', 'v': 0.0009},
#     {'period': '2000-12-31', 'v': -0.0055},
#     {'period': '1999-12-31', 'v': -0.0036}],
#    'ev': [{'period': '2024-12-31', 'v': 2313623},
#     {'period': '2023-12-31', 'v': 1746027},
#     {'period': '2022-12-31', 'v': 1138120},
#     {'period': '2021-12-31', 'v': 1915835},
#     {'period': '2020-12-31', 'v': 1173847},
#     {'period': '2019-12-31', 'v': 909002},
#     {'period': '2018-12-31', 'v': 710776},
#     {'period': '2017-12-31', 'v': 736053},
#     {'period': '2016-12-31', 'v': 540382},
#     {'period': '2015-12-31', 'v': 517119},
#     {'period': '2014-12-31', 'v': 345426},
#     {'period': '2013-12-31', 'v': 360762},
#     {'period': '2012-12-31', 'v': 223200},
#     {'period': '2011-12-31', 'v': 209739},
#     {'period': '2010-12-31', 'v': 179772},
#     {'period': '2009-12-31', 'v': 186503.412},
#     {'period': '2008-12-31', 'v': 88177.428},
#     {'period': '2007-12-31', 'v': 210241.407},
#     {'period': '2006-12-31', 'v': 139611.329},
#     {'period': '2005-12-31', 'v': 124753.826},
#     {'period': '2004-12-31', 'v': 52286.929}],
#    'fcfMargin': [{'period': '2024-12-31', 'v': 0.2079},
#     {'period': '2023-12-31', 'v': 0.2261},
#     {'period': '2022-12-31', 'v': 0.2122},
#     {'period': '2021-12-31', 'v': 0.2601},
#     {'period': '2020-12-31', 'v': 0.2347},
#     {'period': '2019-12-31', 'v': 0.1914},
#     {'period': '2018-12-31', 'v': 0.1669},
#     {'period': '2017-12-31', 'v': 0.2157},
#     {'period': '2016-12-31', 'v': 0.2861},
#     {'period': '2015-12-31', 'v': 0.2217},
#     {'period': '2014-12-31', 'v': 0.182},
#     {'period': '2013-12-31', 'v': 0.2036},
#     {'period': '2012-12-31', 'v': 0.2899},
#     {'period': '2011-12-31', 'v': 0.2935},
#     {'period': '2010-12-31', 'v': 0.2409},
#     {'period': '2009-12-31', 'v': 0.3597},
#     {'period': '2008-12-31', 'v': 0.2521},
#     {'period': '2007-12-31', 'v': 0.2032},
#     {'period': '2006-12-31', 'v': 0.1582},
#     {'period': '2005-12-31', 'v': 0.2617},
#     {'period': '2004-12-31', 'v': 0.1948},
#     {'period': '2003-12-31', 'v': 0.1492},
#     {'period': '2002-12-31', 'v': 0.2686},
#     {'period': '2001-12-31', 'v': 0.2086}],
#    'grossMargin': [{'period': '2024-12-31', 'v': 0.582},
#     {'period': '2023-12-31', 'v': 0.5694},
#     {'period': '2022-12-31', 'v': 0.5538},
#     {'period': '2021-12-31', 'v': 0.5694},
#     {'period': '2020-12-31', 'v': 0.5358},
#     {'period': '2019-12-31', 'v': 0.5558},
#     {'period': '2018-12-31', 'v': 0.5648},
#     {'period': '2017-12-31', 'v': 0.5888},
#     {'period': '2016-12-31', 'v': 0.6108},
#     {'period': '2015-12-31', 'v': 0.6244},
#     {'period': '2014-12-31', 'v': 0.6165},
#     {'period': '2013-12-31', 'v': 0.6039},
#     {'period': '2012-12-31', 'v': 0.6269},
#     {'period': '2011-12-31', 'v': 0.6521},
#     {'period': '2010-12-31', 'v': 0.6447},
#     {'period': '2009-12-31', 'v': 0.6261},
#     {'period': '2008-12-31', 'v': 0.6044},
#     {'period': '2007-12-31', 'v': 0.5993},
#     {'period': '2006-12-31', 'v': 0.6016},
#     {'period': '2005-12-31', 'v': 0.5802},
#     {'period': '2004-12-31', 'v': 0.5394},
#     {'period': '2003-12-31', 'v': 0.5672},
#     {'period': '2002-12-31', 'v': 0.6984},
#     {'period': '2001-12-31', 'v': 0.8252},
#     {'period': '2000-12-31', 'v': 0.673},
#     {'period': '1999-12-31', 'v': -3.1273}],
#    'inventoryTurnover': [{'period': '2022-12-31', 'v': 65.7307},
#     {'period': '2021-12-31', 'v': 116.9009},
#     {'period': '2020-12-31', 'v': 98.1262},
#     {'period': '2019-12-31', 'v': 68.2773},
#     {'period': '2018-12-31', 'v': 64.1692},
#     {'period': '2017-12-31', 'v': 89.6421}],
#    'longtermDebtTotalAsset': [{'period': '2024-12-31', 'v': 0.0242},
#     {'period': '2023-12-31', 'v': 0.0295},
#     {'period': '2022-12-31', 'v': 0.0352},
#     {'period': '2021-12-31', 'v': 0.0357},
#     {'period': '2020-12-31', 'v': 0.0401},
#     {'period': '2019-12-31', 'v': 0.014},
#     {'period': '2018-12-31', 'v': 0.017},
#     {'period': '2017-12-31', 'v': 0.02},
#     {'period': '2016-12-31', 'v': 0.0235},
#     {'period': '2015-12-31', 'v': 0.0135},
#     {'period': '2014-12-31', 'v': 0.0232},
#     {'period': '2013-12-31', 'v': 0.0179},
#     {'period': '2012-12-31', 'v': 0.0319},
#     {'period': '2011-12-31', 'v': 0.0411},
#     {'period': '2010-12-31', 'v': 0}],
#    'longtermDebtTotalCapital': [{'period': '2024-12-31', 'v': 0.0321},
#     {'period': '2023-12-31', 'v': 0.0398},
#     {'period': '2022-12-31', 'v': 0.0474},
#     {'period': '2021-12-31', 'v': 0.0482},
#     {'period': '2020-12-31', 'v': 0.054},
#     {'period': '2019-12-31', 'v': 0.0188},
#     {'period': '2018-12-31', 'v': 0.0217},
#     {'period': '2017-12-31', 'v': 0.0252},
#     {'period': '2016-12-31', 'v': 0.0275},
#     {'period': '2015-12-31', 'v': 0.0159},
#     {'period': '2014-12-31', 'v': 0.0274},
#     {'period': '2013-12-31', 'v': 0.0215},
#     {'period': '2012-12-31', 'v': 0.0387},
#     {'period': '2011-12-31', 'v': 0.0479},
#     {'period': '2010-12-31', 'v': 0}],
#    'longtermDebtTotalEquity': [{'period': '2024-12-31', 'v': 0.0335},
#     {'period': '2023-12-31', 'v': 0.0419},
#     {'period': '2022-12-31', 'v': 0.0502},
#     {'period': '2021-12-31', 'v': 0.051},
#     {'period': '2020-12-31', 'v': 0.0577},
#     {'period': '2019-12-31', 'v': 0.0192},
#     {'period': '2018-12-31', 'v': 0.0222},
#     {'period': '2017-12-31', 'v': 0.0259},
#     {'period': '2016-12-31', 'v': 0.0283},
#     {'period': '2015-12-31', 'v': 0.0166},
#     {'period': '2014-12-31', 'v': 0.0288},
#     {'period': '2013-12-31', 'v': 0.0228},
#     {'period': '2012-12-31', 'v': 0.0417},
#     {'period': '2011-12-31', 'v': 0.0514},
#     {'period': '2010-12-31', 'v': 0}],
#    'netDebtToTotalCapital': [{'period': '2024-12-31', 'v': -0.0293},
#     {'period': '2023-12-31', 'v': -0.0317},
#     {'period': '2022-12-31', 'v': -0.0254},
#     {'period': '2021-12-31', 'v': -0.0226},
#     {'period': '2020-12-31', 'v': -0.0481},
#     {'period': '2019-12-31', 'v': -0.0677},
#     {'period': '2018-12-31', 'v': -0.0699},
#     {'period': '2017-12-31', 'v': -0.0431},
#     {'period': '2016-12-31', 'v': -0.0628},
#     {'period': '2015-12-31', 'v': -0.0902},
#     {'period': '2014-12-31', 'v': -0.1202},
#     {'period': '2013-12-31', 'v': -0.1475},
#     {'period': '2012-12-31', 'v': -0.1196},
#     {'period': '2011-12-31', 'v': -0.0927},
#     {'period': '2010-12-31', 'v': -0.2045},
#     {'period': '2009-12-31', 'v': -0.2832},
#     {'period': '2008-12-31', 'v': -0.3066},
#     {'period': '2007-12-31', 'v': -0.268},
#     {'period': '2006-12-31', 'v': -0.208},
#     {'period': '2005-12-31', 'v': -0.4116},
#     {'period': '2004-12-31', 'v': -0.145},
#     {'period': '2003-12-31', 'v': -0.2337},
#     {'period': '2002-12-31', 'v': -0.236}],
#    'netDebtToTotalEquity': [{'period': '2024-12-31', 'v': -0.0305},
#     {'period': '2023-12-31', 'v': -0.0333},
#     {'period': '2022-12-31', 'v': -0.0269},
#     {'period': '2021-12-31', 'v': -0.0239},
#     {'period': '2020-12-31', 'v': -0.0514},
#     {'period': '2019-12-31', 'v': -0.0692},
#     {'period': '2018-12-31', 'v': -0.0714},
#     {'period': '2017-12-31', 'v': -0.0442},
#     {'period': '2016-12-31', 'v': -0.0646},
#     {'period': '2015-12-31', 'v': -0.0941},
#     {'period': '2014-12-31', 'v': -0.1262},
#     {'period': '2013-12-31', 'v': -0.1564},
#     {'period': '2012-12-31', 'v': -0.1289},
#     {'period': '2011-12-31', 'v': -0.0994},
#     {'period': '2010-12-31', 'v': -0.2198},
#     {'period': '2009-12-31', 'v': -0.2832},
#     {'period': '2008-12-31', 'v': -0.3066},
#     {'period': '2007-12-31', 'v': -0.268},
#     {'period': '2006-12-31', 'v': -0.208},
#     {'period': '2005-12-31', 'v': -0.4116},
#     {'period': '2004-12-31', 'v': -0.1451},
#     {'period': '2003-12-31', 'v': -0.2363},
#     {'period': '2002-12-31', 'v': -0.2496}],
#    'netMargin': [{'period': '2024-12-31', 'v': 0.286},
#     {'period': '2023-12-31', 'v': 0.2401},
#     {'period': '2022-12-31', 'v': 0.212},
#     {'period': '2021-12-31', 'v': 0.2951},
#     {'period': '2020-12-31', 'v': 0.2206},
#     {'period': '2019-12-31', 'v': 0.2122},
#     {'period': '2018-12-31', 'v': 0.2246},
#     {'period': '2017-12-31', 'v': 0.1142},
#     {'period': '2016-12-31', 'v': 0.2158},
#     {'period': '2015-12-31', 'v': 0.218},
#     {'period': '2014-12-31', 'v': 0.2142},
#     {'period': '2013-12-31', 'v': 0.2293},
#     {'period': '2012-12-31', 'v': 0.2332},
#     {'period': '2011-12-31', 'v': 0.2569},
#     {'period': '2010-12-31', 'v': 0.2901},
#     {'period': '2009-12-31', 'v': 0.2757},
#     {'period': '2008-12-31', 'v': 0.1939},
#     {'period': '2007-12-31', 'v': 0.2533},
#     {'period': '2006-12-31', 'v': 0.2902},
#     {'period': '2005-12-31', 'v': 0.2387},
#     {'period': '2004-12-31', 'v': 0.1251},
#     {'period': '2003-12-31', 'v': 0.0721},
#     {'period': '2002-12-31', 'v': 0.2267},
#     {'period': '2001-12-31', 'v': 0.0808},
#     {'period': '2000-12-31', 'v': -0.7688},
#     {'period': '1999-12-31', 'v': -27.6182}],
#    'operatingMargin': [{'period': '2024-12-31', 'v': 0.3211},
#     {'period': '2023-12-31', 'v': 0.2742},
#     {'period': '2022-12-31', 'v': 0.2646},
#     {'period': '2021-12-31', 'v': 0.3055},
#     {'period': '2020-12-31', 'v': 0.2259},
#     {'period': '2019-12-31', 'v': 0.2115},
#     {'period': '2018-12-31', 'v': 0.2012},
#     {'period': '2017-12-31', 'v': 0.2361},
#     {'period': '2016-12-31', 'v': 0.2627},
#     {'period': '2015-12-31', 'v': 0.2582},
#     {'period': '2014-12-31', 'v': 0.2499},
#     {'period': '2013-12-31', 'v': 0.2774},
#     {'period': '2012-12-31', 'v': 0.3005},
#     {'period': '2011-12-31', 'v': 0.3069},
#     {'period': '2010-12-31', 'v': 0.354},
#     {'period': '2009-12-31', 'v': 0.3515},
#     {'period': '2008-12-31', 'v': 0.2541},
#     {'period': '2007-12-31', 'v': 0.3064},
#     {'period': '2006-12-31', 'v': 0.3348},
#     {'period': '2005-12-31', 'v': 0.3286},
#     {'period': '2004-12-31', 'v': 0.2007},
#     {'period': '2003-12-31', 'v': 0.2336},
#     {'period': '2002-12-31', 'v': 0.4243},
#     {'period': '2001-12-31', 'v': 0.1269},
#     {'period': '2000-12-31', 'v': -0.7712},
#     {'period': '1999-12-31', 'v': -29.6182}],
#    'payoutRatio': [{'period': '2024-12-31', 'v': 0.0735}],
#    'pb': [{'period': '2024-12-31', 'v': 7.1475},
#     {'period': '2023-12-31', 'v': 6.1947},
#     {'period': '2022-12-31', 'v': 4.4701},
#     {'period': '2021-12-31', 'v': 7.6375},
#     {'period': '2020-12-31', 'v': 5.326},
#     {'period': '2019-12-31', 'v': 4.5817},
#     {'period': '2018-12-31', 'v': 4.0729},
#     {'period': '2017-12-31', 'v': 4.8707},
#     {'period': '2016-12-31', 'v': 3.9512},
#     {'period': '2015-12-31', 'v': 4.3916},
#     {'period': '2014-12-31', 'v': 3.4521},
#     {'period': '2013-12-31', 'v': 4.2884},
#     {'period': '2012-12-31', 'v': 3.2412},
#     {'period': '2011-12-31', 'v': 3.7066},
#     {'period': '2010-12-31', 'v': 4.1075},
#     {'period': '2009-12-31', 'v': 5.4633},
#     {'period': '2008-12-31', 'v': 3.4291},
#     {'period': '2007-12-31', 'v': 9.534},
#     {'period': '2006-12-31', 'v': 8.4013},
#     {'period': '2005-12-31', 'v': 13.6566},
#     {'period': '2004-12-31', 'v': 17.9962}],
#    'pe': [{'period': '2024-12-31', 'v': 23.2079},
#     {'period': '2023-12-31', 'v': 23.7883},
#     {'period': '2022-12-31', 'v': 19.0922},
#     {'period': '2021-12-31', 'v': 25.2765},
#     {'period': '2020-12-31', 'v': 29.4341},
#     {'period': '2019-12-31', 'v': 26.8744},
#     {'period': '2018-12-31', 'v': 23.538},
#     {'period': '2017-12-31', 'v': 58.6636},
#     {'period': '2016-12-31', 'v': 28.2044},
#     {'period': '2015-12-31', 'v': 32.3249},
#     {'period': '2014-12-31', 'v': 25.3633},
#     {'period': '2013-12-31', 'v': 29.4051},
#    'totalRatio': [{'period': '2024-12-31', 'v': 3.5971},
#     {'period': '2023-12-31', 'v': 3.3811},
#     {'period': '2022-12-31', 'v': 3.3474},
#     {'period': '2021-12-31', 'v': 3.3379},
#     {'period': '2020-12-31', 'v': 3.2926},
#     {'period': '2019-12-31', 'v': 3.7051},
#     {'period': '2018-12-31', 'v': 4.22},
#     {'period': '2017-12-31', 'v': 4.4046},
#     {'period': '2016-12-31', 'v': 5.8851},
#     {'period': '2015-12-31', 'v': 5.4353},
#     {'period': '2014-12-31', 'v': 5.1008},
#     {'period': '2013-12-31', 'v': 4.6978},
#     {'period': '2012-12-31', 'v': 4.2475},
#     {'period': '2011-12-31', 'v': 5.0297},
#     {'period': '2010-12-31', 'v': 4.9829},
#     {'period': '2009-12-31', 'v': 9.0142},
#     {'period': '2008-12-31', 'v': 9.0026},
#     {'period': '2007-12-31', 'v': 9.5747},
#     {'period': '2006-12-31', 'v': 12.8868},
#     {'period': '2005-12-31', 'v': 12.044},
#     {'period': '2004-12-31', 'v': 8.6219},
#     {'period': '2003-12-31', 'v': 3.2418},
#     {'period': '2002-12-31', 'v': 2.8959}]},
#   'quarterly': {'assetTurnoverTTM': [{'period': '2024-12-31', 'v': 0.8223},
#     {'period': '2024-09-30', 'v': 0.8215},
#     {'period': '2024-06-30', 'v': 0.81},
#     {'period': '2024-03-31', 'v': 0.8006},
#     {'period': '2023-12-31', 'v': 0.7924},
#     {'period': '2023-09-30', 'v': 0.7848},
#     {'period': '2023-06-30', 'v': 0.7846},
#     {'period': '2023-03-31', 'v': 0.7861},
#     {'period': '2022-12-31', 'v': 0.788},
#     {'period': '2022-09-30', 'v': 0.7892},
#     {'period': '2022-06-30', 'v': 0.7841},
#     {'period': '2022-03-31', 'v': 0.7728},
#     {'period': '2021-12-31', 'v': 0.7527},
#     {'period': '2021-09-30', 'v': 0.7197},
#     {'period': '2021-06-30', 'v': 0.6876},
#     {'period': '2021-03-31', 'v': 0.6425},
#     {'period': '2020-12-31', 'v': 0.6236},
#     {'period': '2020-09-30', 'v': 0.6094},
#     {'period': '2020-06-30', 'v': 0.6088},
#     {'period': '2020-03-31', 'v': 0.6234},
#     {'period': '2019-12-31', 'v': 0.6217},
#     {'period': '2019-09-30', 'v': 0.6213},
#     {'period': '2019-06-30', 'v': 0.62},
#     {'period': '2019-03-31', 'v': 0.6233},
#     {'period': '2018-12-31', 'v': 0.627},
#     {'period': '2018-09-30', 'v': 0.6203},
#     {'period': '2018-06-30', 'v': 0.6154},
#     {'period': '2018-03-31', 'v': 0.6072},
#     {'period': '2017-12-31', 'v': 0.6007},
#     {'period': '2017-09-30', 'v': 0.5906},
#     {'period': '2017-06-30', 'v': 0.585},
#     {'period': '2017-03-31', 'v': 0.5792},
#     {'period': '2016-12-31', 'v': 0.5718},
#     {'period': '2016-09-30', 'v': 0.5596},
#     {'period': '2016-06-30', 'v': 0.5489},
#     {'period': '2016-03-31', 'v': 0.5376},
#     {'period': '2015-12-31', 'v': 0.5319},
#     {'period': '2015-09-30', 'v': 0.526},
#     {'period': '2015-06-30', 'v': 0.5282},
#     {'period': '2015-03-31', 'v': 0.5321},
#     {'period': '2014-12-31', 'v': 0.5354},
#     {'period': '2014-09-30', 'v': 0.5358},
#     {'period': '2014-06-30', 'v': 0.5359},
#     {'period': '2014-03-31', 'v': 0.5348},
#     {'period': '2013-12-31', 'v': 0.5366},
#     {'period': '2013-09-30', 'v': 0.5468},
#     {'period': '2013-06-30', 'v': 0.564},
#     {'period': '2013-03-31', 'v': 0.5731},
#     {'period': '2012-12-31', 'v': 0.5788},
#     {'period': '2012-09-30', 'v': 0.5695},
#     {'period': '2012-06-30', 'v': 0.561},
#     {'period': '2012-03-31', 'v': 0.5637},
#     {'period': '2011-12-31', 'v': 0.569},
#     {'period': '2011-09-30', 'v': 0.5682},
#     {'period': '2011-06-30', 'v': 0.5648},
#     {'period': '2011-03-31', 'v': 0.5679},
#     {'period': '2010-12-31', 'v': 0.5803},
#     {'period': '2010-09-30', 'v': 0.5966},
#     {'period': '2010-06-30', 'v': 0.62},
#     {'period': '2010-03-31', 'v': 0.6379},
#     {'period': '2009-12-31', 'v': 0.6441},
#     {'period': '2009-09-30', 'v': 0.6566},
#     {'period': '2009-06-30', 'v': 0.6789},
#     {'period': '2009-03-31', 'v': 0.7063},
#     {'period': '2008-12-31', 'v': 0.7304},
#     {'period': '2008-09-30', 'v': 0.7411},
#     {'period': '2008-06-30', 'v': 0.7438},
#     {'period': '2008-03-31', 'v': 0.7417},
#     {'period': '2007-12-31', 'v': 0.7366},
#     {'period': '2007-09-30', 'v': 0.7194},
#     {'period': '2007-06-30', 'v': 0.7106},
#     {'period': '2007-03-31', 'v': 0.7008},
#     {'period': '2006-12-31', 'v': 0.7087},
#     {'period': '2006-09-30', 'v': 0.7216},
#     {'period': '2006-06-30', 'v': 0.7229},
#     {'period': '2006-03-31', 'v': 0.8037},
#     {'period': '2005-12-31', 'v': 0.8743},
#     {'period': '2005-09-30', 'v': 0.9942},
#     {'period': '2005-06-30', 'v': 1.2299},
#     {'period': '2005-03-31', 'v': 1.3318},
#     {'period': '2004-12-31', 'v': 1.4817},
#     {'period': '2004-09-30', 'v': 1.7316}],
#    'bookValue': [{'period': '2024-12-31', 'v': 325084},
#     {'period': '2024-09-30', 'v': 314119},
#     {'period': '2024-06-30', 'v': 300753},
#     {'period': '2024-03-31', 'v': 292844},
#     {'period': '2023-12-31', 'v': 283379},
#     {'period': '2023-09-30', 'v': 273202},
#     {'period': '2023-06-30', 'v': 267141},
#     {'period': '2023-03-31', 'v': 260894},
#     {'period': '2022-12-31', 'v': 256144},
#     {'period': '2022-09-30', 'v': 253626},
#     {'period': '2022-06-30', 'v': 255419},
#     {'period': '2022-03-31', 'v': 254004},
#     {'period': '2021-12-31', 'v': 251635},
#     {'period': '2021-09-30', 'v': 244567},
#     {'period': '2021-06-30', 'v': 237565},
#     {'period': '2021-03-31', 'v': 230013},
#     {'period': '2020-12-31', 'v': 222544},
#     {'period': '2020-09-30', 'v': 212920},
#     {'period': '2020-06-30', 'v': 207322},
#     {'period': '2020-03-31', 'v': 203659},
#     {'period': '2019-12-31', 'v': 201442},
#     {'period': '2019-09-30', 'v': 194969},
#     {'period': '2019-06-30', 'v': 192192},
#     {'period': '2019-03-31', 'v': 183472},
#     {'period': '2018-12-31', 'v': 177628},
#     {'period': '2018-09-30', 'v': 169840},
#     {'period': '2018-06-30', 'v': 162000},
#     {'period': '2018-03-31', 'v': 160825},
#     {'period': '2017-12-31', 'v': 152502},
#     {'period': '2017-09-30', 'v': 157100},
#     {'period': '2017-06-30', 'v': 148286},
#     {'period': '2017-03-31', 'v': 144949},
#     {'period': '2016-12-31', 'v': 139036},
#     {'period': '2016-09-30', 'v': 134103},
#     {'period': '2016-06-30', 'v': 127879},
#     {'period': '2016-03-31', 'v': 123569},
#     {'period': '2015-12-31', 'v': 120331},
#     {'period': '2015-09-30', 'v': 116241},
#     {'period': '2015-06-30', 'v': 111783},
#     {'period': '2015-03-31', 'v': 108448},
#     {'period': '2014-12-31', 'v': 103860},
#     {'period': '2014-09-30', 'v': 98815},
#     {'period': '2014-06-30', 'v': 95749},
#     {'period': '2014-03-31', 'v': 91711},
#     {'period': '2013-12-31', 'v': 87309},
#     {'period': '2013-09-30', 'v': 82989},
#     {'period': '2013-06-30', 'v': 78852},
#     {'period': '2013-03-31', 'v': 75473},
#     {'period': '2012-12-31', 'v': 71715},
#     {'period': '2012-09-30', 'v': 68028},
#     {'period': '2012-06-30', 'v': 64721},
#     {'period': '2012-03-31', 'v': 61712},
#     {'period': '2011-12-31', 'v': 58145},
#     {'period': '2011-09-30', 'v': 54830},
#     {'period': '2011-06-30', 'v': 51991},
#     {'period': '2011-03-31', 'v': 48851},
#     {'period': '2010-12-31', 'v': 46241},
#     {'period': '2010-09-30', 'v': 43290},
#     {'period': '2010-06-30', 'v': 40613},
#     {'period': '2010-03-31', 'v': 38283},
#     {'period': '2009-12-31', 'v': 36004.224},
#     {'period': '2009-09-30', 'v': 33721.753},
#     {'period': '2009-06-30', 'v': 31594.856},
#     {'period': '2009-03-31', 'v': 29848.095},
#     {'period': '2008-12-31', 'v': 28238.862},
#     {'period': '2008-09-30', 'v': 27474.862},
#     {'period': '2008-06-30', 'v': 25913.015},
#     {'period': '2008-03-31', 'v': 24337.535},
#     {'period': '2007-12-31', 'v': 22689.679},
#     {'period': '2007-09-30', 'v': 21036.771},
#     {'period': '2007-06-30', 'v': 19659.608},
#     {'period': '2007-03-31', 'v': 18377.21},
#     {'period': '2006-12-31', 'v': 17039.84},
#     {'period': '2006-09-30', 'v': 14397.087},
#     {'period': '2006-06-30', 'v': 13357.008},
#     {'period': '2006-03-31', 'v': 10243.265},
#     {'period': '2005-12-31', 'v': 9418.957},
#     {'period': '2005-09-30', 'v': 8793.068},
#     {'period': '2005-06-30', 'v': 3953.857},
#     {'period': '2005-03-31', 'v': 3426.862},
#     {'period': '2004-12-31', 'v': 2929.056},
#     {'period': '2004-09-30', 'v': 2589.023}],
#    'cashRatio': [{'period': '2024-12-31', 'v': 0.2633019905298355},
#     {'period': '2024-09-30', 'v': 0.24700815563778572},
#     {'period': '2024-06-30', 'v': 0.34942820838627703},
#     {'period': '2024-03-31', 'v': 0.31810330272608023},
#     {'period': '2023-12-31', 'v': 0.29393502334563765},
#     {'period': '2023-09-30', 'v': 0.3557795932556927},
#     {'period': '2023-06-30', 'v': 0.3336679149133305},
#     {'period': '2023-03-31', 'v': 0.3765068115142185},
#     {'period': '2022-12-31', 'v': 0.3157142857142857},
#     {'period': '2022-09-30', 'v': 0.33319692629473013},
#     {'period': '2022-06-30', 'v': 0.2923362779932849},
#     {'period': '2022-03-31', 'v': 0.33715374184800156},
#     {'period': '2021-12-31', 'v': 0.32597192392691504},
#     {'period': '2021-09-30', 'v': 0.3839144087274611},
#     {'period': '2021-06-30', 'v': 0.42392493855510305},
#     {'period': '2021-03-31', 'v': 0.4800822317999026},
#     {'period': '2020-12-31', 'v': 0.4656543618256677},
#     {'period': '2020-09-30', 'v': 0.4176141078838174},
#     {'period': '2020-06-30', 'v': 0.4063860002748637},
#     {'period': '2020-03-31', 'v': 0.48879046505262636},
#     {'period': '2019-12-31', 'v': 0.40905773866124145},
#     {'period': '2019-09-30', 'v': 0.40872934937793187},
#     {'period': '2019-06-30', 'v': 0.4482972972972973},
#     {'period': '2019-03-31', 'v': 0.5484961329132054},
#     {'period': '2018-12-31', 'v': 0.4824090121317158},
#     {'period': '2018-09-30', 'v': 0.4294750966422798},
#     {'period': '2018-06-30', 'v': 0.473129786309066},
#     {'period': '2018-03-31', 'v': 0.49846420414271086},
#     {'period': '2017-12-31', 'v': 0.4430798494810404},
#     {'period': '2017-09-30', 'v': 0.5113323346059053},
#     {'period': '2017-06-30', 'v': 0.8408348943002408},
#     {'period': '2017-03-31', 'v': 1.188515993707394},
#     {'period': '2016-12-31', 'v': 0.7709477202196228},
#     {'period': '2016-09-30', 'v': 0.6567059973469245},
#     {'period': '2016-06-30', 'v': 0.7858255002595006},
#     {'period': '2016-03-31', 'v': 0.8545012440624293},
#     {'period': '2015-12-31', 'v': 0.8570170895908855},
#     {'period': '2015-09-30', 'v': 0.9789239854797638},
#     {'period': '2015-06-30', 'v': 1.0628383826748071},
#     {'period': '2015-03-31', 'v': 1.1841517857142858},
#     {'period': '2014-12-31', 'v': 1.0934501460158532},
#     {'period': '2014-09-30', 'v': 0.8708147321428571},
#     {'period': '2014-06-30', 'v': 1.1475697490787857},
#     {'period': '2014-03-31', 'v': 0.8934234787953288},
#     {'period': '2013-12-31', 'v': 1.1879557455368368},
#     {'period': '2013-09-30', 'v': 1.0529879101899828},
#     {'period': '2013-06-30', 'v': 1.0544719159762541},
#     {'period': '2013-03-31', 'v': 1.1602022336251132},
#     {'period': '2012-12-31', 'v': 1.0307595731324546},
#     {'period': '2012-09-30', 'v': 1.126506858805598},
#     {'period': '2012-06-30', 'v': 1.1004419731964643},
#     {'period': '2012-03-31', 'v': 2.371997536440156},
#     {'period': '2011-12-31', 'v': 1.1200493660944688},
# ...
#     {'period': '2013-03-31', 'v': 68149},
#     {'period': '2012-12-31', 'v': 64242},
#     {'period': '2012-09-30', 'v': 60274},
#     {'period': '2012-06-30', 'v': 56859},
#     {'period': '2012-03-31', 'v': 60171},
#     {'period': '2011-12-31', 'v': 56567},
#     {'period': '2011-09-30', 'v': 53356},
#     {'period': '2011-06-30', 'v': 50610},
#     {'period': '2011-03-31', 'v': 47835},
#     {'period': '2010-12-31', 'v': 45197},
#     {'period': '2010-09-30', 'v': 42297},
#     {'period': '2010-06-30', 'v': 39709},
#     {'period': '2010-03-31', 'v': 37493},
#     {'period': '2009-12-31', 'v': 35229.286},
#     {'period': '2009-09-30', 'v': 32898.505},
#     {'period': '2009-06-30', 'v': 30738.47},
#     {'period': '2009-03-31', 'v': 28937.751},
#     {'period': '2008-12-31', 'v': 27242.172},
#     {'period': '2008-09-30', 'v': 26427.145},
#     {'period': '2008-06-30', 'v': 24774.024},
#     {'period': '2008-03-31', 'v': 23133.563},
#     {'period': '2007-12-31', 'v': 22243.083},
#     {'period': '2007-09-30', 'v': 20551.519},
#     {'period': '2007-06-30', 'v': 19320.029},
#     {'period': '2007-03-31', 'v': 18050.684},
#     {'period': '2006-12-31', 'v': 16692.999},
#     {'period': '2006-09-30', 'v': 14219.681},
#     {'period': '2006-06-30', 'v': 13210.407},
#     {'period': '2006-03-31', 'v': 10082.692},
#     {'period': '2005-12-31', 'v': 9336.174},
#     {'period': '2005-09-30', 'v': 8735.862},
#     {'period': '2005-06-30', 'v': 3891.923},
#     {'period': '2005-03-31', 'v': 3365.096},
#     {'period': '2004-12-31', 'v': 2857.987},
#     {'period': '2004-09-30', 'v': 2545.363}],
#    'totalDebtToEquity': [{'period': '2024-12-31', 'v': 0.0373},
#     {'period': '2024-09-30', 'v': 0.0467},
#     {'period': '2024-06-30', 'v': 0.0471},
#     {'period': '2024-03-31', 'v': 0.0463},
#     {'period': '2023-12-31', 'v': 0.0516},
#     {'period': '2023-09-30', 'v': 0.0556},
#     {'period': '2023-06-30', 'v': 0.0562},
#     {'period': '2023-03-31', 'v': 0.0578},
#     {'period': '2022-12-31', 'v': 0.0586},
#     {'period': '2022-09-30', 'v': 0.0594},
#     {'period': '2022-06-30', 'v': 0.058},
#     {'period': '2022-03-31', 'v': 0.0589},
#     {'period': '2021-12-31', 'v': 0.0593},
#     {'period': '2021-09-30', 'v': 0.0594},
#     {'period': '2021-06-30', 'v': 0.0608},
#     {'period': '2021-03-31', 'v': 0.0651},
#     {'period': '2020-12-31', 'v': 0.0675},
#     {'period': '2020-09-30', 'v': 0.0706},
#     {'period': '2020-06-30', 'v': 0.0249},
#     {'period': '2020-03-31', 'v': 0.0246},
#     {'period': '2019-12-31', 'v': 0.0226},
#     {'period': '2019-09-30', 'v': 0.0209},
#     {'period': '2019-06-30', 'v': 0.0212},
#     {'period': '2019-03-31', 'v': 0.0222},
#     {'period': '2018-12-31', 'v': 0.0226},
#     {'period': '2018-09-30', 'v': 0.0235},
#     {'period': '2018-06-30', 'v': 0.0246},
#     {'period': '2018-03-31', 'v': 0.033},
#     {'period': '2017-12-31', 'v': 0.026},
#     {'period': '2017-09-30', 'v': 0.0252},
#     {'period': '2017-06-30', 'v': 0.0267},
#     {'period': '2017-03-31', 'v': 0.0272},
#     {'period': '2016-12-31', 'v': 0.0283},
#     {'period': '2016-09-30', 'v': 0.0294},
#     {'period': '2016-06-30', 'v': 0.0329},
#     {'period': '2016-03-31', 'v': 0.0421},
#     {'period': '2015-12-31', 'v': 0.0434},
#     {'period': '2015-09-30', 'v': 0.045},
#     {'period': '2015-06-30', 'v': 0.0468},
#     {'period': '2015-03-31', 'v': 0.0483},
#     {'period': '2014-12-31', 'v': 0.0504},
#     {'period': '2014-09-30', 'v': 0.053},
#     {'period': '2014-06-30', 'v': 0.0547},
#     {'period': '2014-03-31', 'v': 0.0681},
#     {'period': '2013-12-31', 'v': 0.0601},
#     {'period': '2013-09-30', 'v': 0.0632},
#     {'period': '2013-06-30', 'v': 0.0633},
#     {'period': '2013-03-31', 'v': 0.0681},
#     {'period': '2012-12-31', 'v': 0.0772},
#     {'period': '2012-09-30', 'v': 0.0912},
#     {'period': '2012-06-30', 'v': 0.0959},
#     {'period': '2012-03-31', 'v': 0.0884},
#     {'period': '2011-12-31', 'v': 0.0723},
#     {'period': '2011-09-30', 'v': 0.0767},
#     {'period': '2011-06-30', 'v': 0.0808},
#     {'period': '2011-03-31', 'v': 0.0658},
#     {'period': '2010-12-31', 'v': 0.0749},
#     {'period': '2010-09-30', 'v': 0.049},
#     {'period': '2010-06-30', 'v': 0},
#     {'period': '2010-03-31', 'v': 0},
#     {'period': '2009-12-31', 'v': 0},
#     {'period': '2009-09-30', 'v': 0},
#     {'period': '2009-06-30', 'v': 0},
#     {'period': '2009-03-31', 'v': 0},
#     {'period': '2008-12-31', 'v': 0},
#     {'period': '2008-09-30', 'v': 0},
#     {'period': '2008-06-30', 'v': 0},
#     {'period': '2008-03-31', 'v': 0},
#     {'period': '2007-12-31', 'v': 0},
#     {'period': '2007-09-30', 'v': 0},
#     {'period': '2007-06-30', 'v': 0},
#     {'period': '2007-03-31', 'v': 0},
#     {'period': '2006-12-31', 'v': 0},
#     {'period': '2006-09-30', 'v': 0},
#     {'period': '2006-06-30', 'v': 0},
#     {'period': '2006-03-31', 'v': 0},
#     {'period': '2005-12-31', 'v': 0},
#     {'period': '2005-09-30', 'v': 0},
#     {'period': '2005-06-30', 'v': 0.0001},
#     {'period': '2005-03-31', 'v': 0.0004},
#     {'period': '2004-12-31', 'v': 0.0006},
#     {'period': '2004-09-30', 'v': 0.0012},
#     {'period': '2004-06-30', 'v': 0.0041},
#     {'period': '2004-03-31', 'v': 0.0073},
#     {'period': '2003-12-31', 'v': 0.011}],
#    'totalDebtToTotalAsset': [{'period': '2024-12-31', 'v': 0.0269},
#     {'period': '2024-09-30', 'v': 0.0341},
#     {'period': '2024-06-30', 'v': 0.0341},
#     {'period': '2024-03-31', 'v': 0.0333},
#     {'period': '2023-12-31', 'v': 0.0363},
#     {'period': '2023-09-30', 'v': 0.0383},
#     {'period': '2023-06-30', 'v': 0.0392},
#     {'period': '2023-03-31', 'v': 0.0408},
#     {'period': '2022-12-31', 'v': 0.0411},
#     {'period': '2022-09-30', 'v': 0.0421},
#     {'period': '2022-06-30', 'v': 0.0417},
#     {'period': '2022-03-31', 'v': 0.0419},
#     {'period': '2021-12-31', 'v': 0.0416},
#     {'period': '2021-09-30', 'v': 0.0418},
#     {'period': '2021-06-30', 'v': 0.0431},
#     {'period': '2021-03-31', 'v': 0.0458},
#     {'period': '2020-12-31', 'v': 0.047},
#     {'period': '2020-09-30', 'v': 0.0502},
#     {'period': '2020-06-30', 'v': 0.0185},
#     {'period': '2020-03-31', 'v': 0.0183},
#     {'period': '2019-12-31', 'v': 0.0165},
#     {'period': '2019-09-30', 'v': 0.0155},
#     {'period': '2019-06-30', 'v': 0.0158},
#     {'period': '2019-03-31', 'v': 0.0166},
#     {'period': '2018-12-31', 'v': 0.0172},
#     {'period': '2018-09-30', 'v': 0.018},
#     {'period': '2018-06-30', 'v': 0.0188},
#     {'period': '2018-03-31', 'v': 0.0256},
#     {'period': '2017-12-31', 'v': 0.0201},
#     {'period': '2017-09-30', 'v': 0.0209},
#     {'period': '2017-06-30', 'v': 0.0221},
#     {'period': '2017-03-31', 'v': 0.0228},
#     {'period': '2016-12-31', 'v': 0.0235},
#     {'period': '2016-09-30', 'v': 0.0246},
#     {'period': '2016-06-30', 'v': 0.0272},
#     {'period': '2016-03-31', 'v': 0.0348},
#     {'period': '2015-12-31', 'v': 0.0354},
#     {'period': '2015-09-30', 'v': 0.0363},
#     {'period': '2015-06-30', 'v': 0.0377},
#     {'period': '2015-03-31', 'v': 0.0392},
#     {'period': '2014-12-31', 'v': 0.0405},
#     {'period': '2014-09-30', 'v': 0.0417},
#     {'period': '2014-06-30', 'v': 0.0431},
#     {'period': '2014-03-31', 'v': 0.0536},
#     {'period': '2013-12-31', 'v': 0.0473},
#     {'period': '2013-09-30', 'v': 0.0499},
#     {'period': '2013-06-30', 'v': 0.0493},
#     {'period': '2013-03-31', 'v': 0.0531},
#     {'period': '2012-12-31', 'v': 0.059},
#     {'period': '2012-09-30', 'v': 0.0692},
#     {'period': '2012-06-30', 'v': 0.0721},
#     {'period': '2012-03-31', 'v': 0.0707},
#     {'period': '2011-12-31', 'v': 0.0579},
#     {'period': '2011-09-30', 'v': 0.0608},
#     {'period': '2011-06-30', 'v': 0.0648},
#     {'period': '2011-03-31', 'v': 0.0536},
#     {'period': '2010-12-31', 'v': 0.0599},
#     {'period': '2010-09-30', 'v': 0.0398},
#     {'period': '2010-06-30', 'v': 0},
#     {'period': '2010-03-31', 'v': 0},
#     {'period': '2009-12-31', 'v': 0},
#     {'period': '2009-09-30', 'v': 0},
#     {'period': '2009-06-30', 'v': 0},
#     {'period': '2009-03-31', 'v': 0},
#     {'period': '2008-12-31', 'v': 0},
#     {'period': '2008-09-30', 'v': 0},
#     {'period': '2008-06-30', 'v': 0},
#     {'period': '2008-03-31', 'v': 0},
#     {'period': '2007-12-31', 'v': 0},
#     {'period': '2007-09-30', 'v': 0},
#     {'period': '2007-06-30', 'v': 0},
#     {'period': '2007-03-31', 'v': 0},
#     {'period': '2006-12-31', 'v': 0},
#     {'period': '2006-09-30', 'v': 0},
#     {'period': '2006-06-30', 'v': 0},
#     {'period': '2006-03-31', 'v': 0},
#     {'period': '2005-12-31', 'v': 0},
#     {'period': '2005-09-30', 'v': 0},
#     {'period': '2005-06-30', 'v': 0.0001},
#     {'period': '2005-03-31', 'v': 0.0003},
#     {'period': '2004-12-31', 'v': 0.0006},
#     {'period': '2004-09-30', 'v': 0.0011},
#     {'period': '2004-06-30', 'v': 0.0032},
#     {'period': '2004-03-31', 'v': 0.005},
#     {'period': '2003-12-31', 'v': 0.0076}],
#    'totalDebtToTotalCapital': [{'period': '2024-12-31', 'v': 0.0359},
#     {'period': '2024-09-30', 'v': 0.0446},
#     {'period': '2024-06-30', 'v': 0.045},
#     {'period': '2024-03-31', 'v': 0.0442},
#     {'period': '2023-12-31', 'v': 0.049},
#     {'period': '2023-09-30', 'v': 0.0526},
#     {'period': '2023-06-30', 'v': 0.0532},
#     {'period': '2023-03-31', 'v': 0.0546},
#     {'period': '2022-12-31', 'v': 0.0553},
#     {'period': '2022-09-30', 'v': 0.0561},
#     {'period': '2022-06-30', 'v': 0.0548},
#     {'period': '2022-03-31', 'v': 0.0557},
#     {'period': '2021-12-31', 'v': 0.056},
#     {'period': '2021-09-30', 'v': 0.0561},
#     {'period': '2021-06-30', 'v': 0.0573},
#     {'period': '2021-03-31', 'v': 0.0611},
#     {'period': '2020-12-31', 'v': 0.0633},
#     {'period': '2020-09-30', 'v': 0.0659},
#     {'period': '2020-06-30', 'v': 0.0243},
#     {'period': '2020-03-31', 'v': 0.024},
#     {'period': '2019-12-31', 'v': 0.0221},
#     {'period': '2019-09-30', 'v': 0.0205},
#     {'period': '2019-06-30', 'v': 0.0208},
#     {'period': '2019-03-31', 'v': 0.0217},
#     {'period': '2018-12-31', 'v': 0.0221},
#     {'period': '2018-09-30', 'v': 0.0229},
#     {'period': '2018-06-30', 'v': 0.024},
#     {'period': '2018-03-31', 'v': 0.0319},
#     {'period': '2017-12-31', 'v': 0.0254},
#     {'period': '2017-09-30', 'v': 0.0246},
#     {'period': '2017-06-30', 'v': 0.026},
#     {'period': '2017-03-31', 'v': 0.0264},
#     {'period': '2016-12-31', 'v': 0.0275},
#     {'period': '2016-09-30', 'v': 0.0285},
#     {'period': '2016-06-30', 'v': 0.0318},
#     {'period': '2016-03-31', 'v': 0.0404},
#     {'period': '2015-12-31', 'v': 0.0416},
#     {'period': '2015-09-30', 'v': 0.0431},
#     {'period': '2015-06-30', 'v': 0.0447},
#     {'period': '2015-03-31', 'v': 0.046},
#     {'period': '2014-12-31', 'v': 0.048},
#     {'period': '2014-09-30', 'v': 0.0503},
#     {'period': '2014-06-30', 'v': 0.0519},
#     {'period': '2014-03-31', 'v': 0.0637},
#     {'period': '2013-12-31', 'v': 0.0567},
#     {'period': '2013-09-30', 'v': 0.0595},
#     {'period': '2013-06-30', 'v': 0.0595},
#     {'period': '2013-03-31', 'v': 0.0637},
#     {'period': '2012-12-31', 'v': 0.0717},
#     {'period': '2012-09-30', 'v': 0.0836},
#     {'period': '2012-06-30', 'v': 0.0875},
#     {'period': '2012-03-31', 'v': 0.0812},
#     {'period': '2011-12-31', 'v': 0.0674},
#     {'period': '2011-09-30', 'v': 0.0712},
#     {'period': '2011-06-30', 'v': 0.0748},
#     {'period': '2011-03-31', 'v': 0.0618},
#     {'period': '2010-12-31', 'v': 0.0697},
#     {'period': '2010-09-30', 'v': 0.0467},
#     {'period': '2010-06-30', 'v': 0},
#     {'period': '2010-03-31', 'v': 0},
#     {'period': '2009-12-31', 'v': 0},
#     {'period': '2009-09-30', 'v': 0},
#     {'period': '2009-06-30', 'v': 0},
#     {'period': '2009-03-31', 'v': 0},
#     {'period': '2008-12-31', 'v': 0},
#     {'period': '2008-09-30', 'v': 0},
#     {'period': '2008-06-30', 'v': 0},
#     {'period': '2008-03-31', 'v': 0},
#     {'period': '2007-12-31', 'v': 0},
#     {'period': '2007-09-30', 'v': 0},
#     {'period': '2007-06-30', 'v': 0},
#     {'period': '2007-03-31', 'v': 0},
#     {'period': '2006-12-31', 'v': 0},
#     {'period': '2006-09-30', 'v': 0},
#     {'period': '2006-06-30', 'v': 0},
#     {'period': '2006-03-31', 'v': 0},
#     {'period': '2005-12-31', 'v': 0},
#     {'period': '2005-09-30', 'v': 0},
#     {'period': '2005-06-30', 'v': 0.0001},
#     {'period': '2005-03-31', 'v': 0.0004},
#     {'period': '2004-12-31', 'v': 0.0006},
#     {'period': '2004-09-30', 'v': 0.0012},
#     {'period': '2004-06-30', 'v': 0.0041},
#     {'period': '2004-03-31', 'v': 0.0072},
#     {'period': '2003-12-31', 'v': 0.0108}],
#    'totalRatio': [{'period': '2024-12-31', 'v': 3.5971},
#     {'period': '2024-09-30', 'v': 3.7045},
#     {'period': '2024-06-30', 'v': 3.6378},
#     {'period': '2024-03-31', 'v': 3.5575},
#     {'period': '2023-12-31', 'v': 3.3811},
#     {'period': '2023-09-30', 'v': 3.212},
#     {'period': '2023-06-30', 'v': 3.3049},
#     {'period': '2023-03-31', 'v': 3.4024},
#     {'period': '2022-12-31', 'v': 3.3474},
#     {'period': '2022-09-30', 'v': 3.4241},
#     {'period': '2022-06-30', 'v': 3.5602},
#     {'period': '2022-03-31', 'v': 3.4639},
#     {'period': '2021-12-31', 'v': 3.3379},
#     {'period': '2021-09-30', 'v': 3.3782},
#     {'period': '2021-06-30', 'v': 3.4285},
#     {'period': '2021-03-31', 'v': 3.3693},
#     {'period': '2020-12-31', 'v': 3.2926},
#     {'period': '2020-09-30', 'v': 3.4666},
#     {'period': '2020-06-30', 'v': 3.9131},
#     {'period': '2020-03-31', 'v': 3.9201},
#     {'period': '2019-12-31', 'v': 3.7051},
#     {'period': '2019-09-30', 'v': 3.864},
#     {'period': '2019-06-30', 'v': 3.9609},
#     {'period': '2019-03-31', 'v': 3.9651},
#     {'period': '2018-12-31', 'v': 4.22},
#     {'period': '2018-09-30', 'v': 4.2852},
#     {'period': '2018-06-30', 'v': 4.2655},
#     {'period': '2018-03-31', 'v': 4.4879},
#     {'period': '2017-12-31', 'v': 4.4046},
#     {'period': '2017-09-30', 'v': 5.8434},
#     {'period': '2017-06-30', 'v': 5.8883},
#     {'period': '2017-03-31', 'v': 6.2127},
#     {'period': '2016-12-31', 'v': 5.8851},
#     {'period': '2016-09-30', 'v': 6.1887},
#     {'period': '2016-06-30', 'v': 5.8415},
#     {'period': '2016-03-31', 'v': 5.7203},
#     {'period': '2015-12-31', 'v': 5.4353},
#     {'period': '2015-09-30', 'v': 5.1455},
#     {'period': '2015-06-30', 'v': 5.1364},
#     {'period': '2015-03-31', 'v': 5.3463},
#     {'period': '2014-12-31', 'v': 5.1008},
#     {'period': '2014-09-30', 'v': 4.6644},
#     {'period': '2014-06-30', 'v': 4.7027},
#     {'period': '2014-03-31', 'v': 4.6958},
#     {'period': '2013-12-31', 'v': 4.6978},
#     {'period': '2013-09-30', 'v': 4.7587},
#     {'period': '2013-06-30', 'v': 4.5312},
#     {'period': '2013-03-31', 'v': 4.5569},
#     {'period': '2012-12-31', 'v': 4.2475},
#     {'period': '2012-09-30', 'v': 4.1346},
#     {'period': '2012-06-30', 'v': 4.0343},
#     {'period': '2012-03-31', 'v': 4.999},
#     {'period': '2011-12-31', 'v': 5.0297},
#     {'period': '2011-09-30', 'v': 4.8456},
#     {'period': '2011-06-30', 'v': 5.0397},
#     {'period': '2011-03-31', 'v': 5.3974},
#     {'period': '2010-12-31', 'v': 4.9829},
#     {'period': '2010-09-30', 'v': 5.3066},
#     {'period': '2010-06-30', 'v': 6.4646},
#     {'period': '2010-03-31', 'v': 9.3442},
#     {'period': '2009-12-31', 'v': 9.0142},
#     {'period': '2009-09-30', 'v': 9.4705},
#     {'period': '2009-06-30', 'v': 9.8652},
#     {'period': '2009-03-31', 'v': 9.1442},
#     {'period': '2008-12-31', 'v': 9.0026},
#     {'period': '2008-09-30', 'v': 9.2455},
#     {'period': '2008-06-30', 'v': 8.9323},
#     {'period': '2008-03-31', 'v': 8.4485},
#     {'period': '2007-12-31', 'v': 9.5747},
#     {'period': '2007-09-30', 'v': 10.131},
#     {'period': '2007-06-30', 'v': 12.1432},
#     {'period': '2007-03-31', 'v': 12.2177},
#     {'period': '2006-12-31', 'v': 12.8868},
#     {'period': '2006-09-30', 'v': 12.1076},
#     {'period': '2006-06-30', 'v': 13.8557},
#     {'period': '2006-03-31', 'v': 10.7406},
#     {'period': '2005-12-31', 'v': 12.044},
#     {'period': '2005-09-30', 'v': 14.3647},
#     {'period': '2005-06-30', 'v': 8.27},
#     {'period': '2005-03-31', 'v': 8.8179},
#     {'period': '2004-12-31', 'v': 8.6219},
#     {'period': '2004-09-30', 'v': 9.6446},
#     {'period': '2004-06-30', 'v': 4.2699},
#     {'period': '2004-03-31', 'v': 3.1955},
#     {'period': '2003-12-31', 'v': 3.2418}]}},
#  'symbol': 'GOOGL'}

# %%
metrics_df = pd.json_normalize(metrics["series"]["annual"]["pe"])
metrics_df
# Out:
#         period         v
# 0   2024-12-31   23.2079
# 1   2023-12-31   23.7883
# 2   2022-12-31   19.0922
# 3   2021-12-31   25.2765
# 4   2020-12-31   29.4341
# 5   2019-12-31   26.8744
# 6   2018-12-31   23.5380
# 7   2017-12-31   58.6636
# 8   2016-12-31   28.2044
# 9   2015-12-31   32.3249
# 10  2014-12-31   25.3633
# 11  2013-12-31   29.4051
# 12  2012-12-31   21.6486
# 13  2011-12-31   22.1339
# 14  2010-12-31   22.3324
# 15  2009-12-31   30.1668
# 16  2008-12-31   22.9092
# 17  2007-12-31   51.4599
# 18  2006-12-31   46.5178
# 19  2005-12-31   87.7789
# 20  2004-12-31  132.0706

# %%
current_year = metrics_df.iloc[0]['v']
one_year = metrics_df.iloc[1]['v']

# %%
difference = one_year - current_year
percentage_difference = difference/current_year
percentage = f"{percentage_difference:.2%}"
percentage
# Out:
# '2.50%'

# %%
# function

def calc_percentage_difference(current_val, previous_val):
    difference = current_val - previous_val
    percentage_difference = difference/previous_val
    percentage = f"{percentage_difference:.2%}"
    return percentage

# %%
calc_percentage_difference(current_year, one_year)
# Out:
# '-2.44%'

# %%
def make_pe_diff(period):
    metrics = finnhub_client.get_company_basic_financials(ticker, 'all')
    peRatio = metrics["series"]["annual"]["pe"]
    df = pd.json_normalize(peRatio)

    current_year = metrics_df.iloc[period]['v']
    prev_year = metrics_df.iloc[period]['v']

    difference = calc_percentage_difference(current_year, prev_year)

# %% [markdown]
# # Diff function for FMP

# %%
from services.fmp_api_client import FMP_APIClient, get_fmp_client
FMP_API_KEY = "OSrMm0u3iB8mz1iJMaK0XQno7DyqQKRw"
fmp_api = get_fmp_client(FMP_API_KEY)
# Out:
# 2025-03-09 17:12:47.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 17:12:47.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 17:12:47.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 17:12:47.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-09 17:12:47.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
incomeStatement_df = fmp_api.get_income_statement(ticker)
print(incomeStatement_df.columns)
# Out:
# Index(['date', 'symbol', 'reportedCurrency', 'cik', 'fillingDate',
#        'acceptedDate', 'calendarYear', 'period', 'revenue', 'costOfRevenue',
#        'grossProfit', 'grossProfitRatio', 'researchAndDevelopmentExpenses',
#        'generalAndAdministrativeExpenses', 'sellingAndMarketingExpenses',
#        'sellingGeneralAndAdministrativeExpenses', 'otherExpenses',
#        'operatingExpenses', 'costAndExpenses', 'interestIncome',
#        'interestExpense', 'depreciationAndAmortization', 'ebitda',
#        'ebitdaratio', 'operatingIncome', 'operatingIncomeRatio',
#        'totalOtherIncomeExpensesNet', 'incomeBeforeTax',
#        'incomeBeforeTaxRatio', 'incomeTaxExpense', 'netIncome',
#        'netIncomeRatio', 'eps', 'epsdiluted', 'weightedAverageShsOut',
#        'weightedAverageShsOutDil', 'link', 'finalLink'],
#       dtype='object')

# %%
balancesheet_df = fmp_api.get_balance_sheet(ticker)
print(balancesheet_df.columns)
# Out:
# Index(['date', 'symbol', 'reportedCurrency', 'cik', 'fillingDate',
#        'acceptedDate', 'calendarYear', 'period', 'cashAndCashEquivalents',
#        'shortTermInvestments', 'cashAndShortTermInvestments', 'netReceivables',
#        'inventory', 'otherCurrentAssets', 'totalCurrentAssets',
#        'propertyPlantEquipmentNet', 'goodwill', 'intangibleAssets',
#        'goodwillAndIntangibleAssets', 'longTermInvestments', 'taxAssets',
#        'otherNonCurrentAssets', 'totalNonCurrentAssets', 'otherAssets',
#        'totalAssets', 'accountPayables', 'shortTermDebt', 'taxPayables',
#        'deferredRevenue', 'otherCurrentLiabilities', 'totalCurrentLiabilities',
#        'longTermDebt', 'deferredRevenueNonCurrent',
#        'deferredTaxLiabilitiesNonCurrent', 'otherNonCurrentLiabilities',
#        'totalNonCurrentLiabilities', 'otherLiabilities',
#        'capitalLeaseObligations', 'totalLiabilities', 'preferredStock',
#        'commonStock', 'retainedEarnings',
#        'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalEquity', 'totalLiabilitiesAndStockholdersEquity',
#        'minorityInterest', 'totalLiabilitiesAndTotalEquity',
#        'totalInvestments', 'totalDebt', 'netDebt', 'link', 'finalLink'],
#       dtype='object')

# %%
cashflow_df = fmp_api.get_cashflow_statement(ticker)
print(cashflow_df.columns)
# Out:
# Index(['date', 'symbol', 'reportedCurrency', 'cik', 'fillingDate',
#        'acceptedDate', 'calendarYear', 'period', 'netIncome',
#        'depreciationAndAmortization', 'deferredIncomeTax',
#        'stockBasedCompensation', 'changeInWorkingCapital',
#        'accountsReceivables', 'inventory', 'accountsPayables',
#        'otherWorkingCapital', 'otherNonCashItems',
#        'netCashProvidedByOperatingActivities',
#        'investmentsInPropertyPlantAndEquipment', 'acquisitionsNet',
#        'purchasesOfInvestments', 'salesMaturitiesOfInvestments',
#        'otherInvestingActivites', 'netCashUsedForInvestingActivites',
#        'debtRepayment', 'commonStockIssued', 'commonStockRepurchased',
#        'dividendsPaid', 'otherFinancingActivites',
#        'netCashUsedProvidedByFinancingActivities',
#        'effectOfForexChangesOnCash', 'netChangeInCash', 'cashAtEndOfPeriod',
#        'cashAtBeginningOfPeriod', 'operatingCashFlow', 'capitalExpenditure',
#        'freeCashFlow', 'link', 'finalLink'],
#       dtype='object')

# %% [markdown]
# ## Gemini Testing

# %%
import os
import google.generativeai as genai

genai.configure(api_key="AIzaSyDeEKkLTe_Gbv0jTn4Ormx5OUy8cuz8ahA")

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-pro",
  generation_config=generation_config,
  system_instruction="You are a an assistant in a investment learning app called EasyStock Learner. Your role is to predict the stock rating of a company given its financial data and give the reasoning behind the rating (either buy or sell). Apart from that your role is also to help users understand the meaning behind the different metrics and ratios in finance. You are required to analyse time series financial data and generate an explanation of the performance of the metric. Be concise and start directly with insights.",
)

chat_session = model.start_chat(
  history=[
  ]
)

response = chat_session.send_message("What are you")

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 import os
#       2 import google.generativeai as genai
# ----> 4 genai.configure(api_key=os.environ["AIzaSyDeEKkLTe_Gbv0jTn4Ormx5OUy8cuz8ahA"])
#       6 # Create the model
#       7 generation_config = {
#       8   "temperature": 1,
#       9   "top_p": 0.95,
#    (...)
#      12   "response_mime_type": "text/plain",
#      13 }
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'AIzaSyDeEKkLTe_Gbv0jTn4Ormx5OUy8cuz8ahA'
