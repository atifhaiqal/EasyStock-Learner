# %% [markdown]
# # List of SP500 Companies
# Data source: https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks?resource=download

# %%
import pandas as pd 
import numpy as np

# %%
sp500_df = pd.read_csv("sp500_companies.csv")
sp500_df
# Out:
#     Exchange Symbol                    Shortname                     Longname  \
# 0        NMS   AAPL                   Apple Inc.                   Apple Inc.
# 1        NMS   NVDA           NVIDIA Corporation           NVIDIA Corporation
# 2        NMS   MSFT        Microsoft Corporation        Microsoft Corporation
# 3        NMS   AMZN             Amazon.com, Inc.             Amazon.com, Inc.
# 4        NMS  GOOGL                Alphabet Inc.                Alphabet Inc.
# ..       ...    ...                          ...                          ...
# 497      NMS    CZR  Caesars Entertainment, Inc.  Caesars Entertainment, Inc.
# 498      NYQ    BWA              BorgWarner Inc.              BorgWarner Inc.
# 499      NMS   QRVO                  Qorvo, Inc.                  Qorvo, Inc.
# 500      NYQ    FMC              FMC Corporation              FMC Corporation
# 501      NYQ   AMTM       Amentum Holdings, Inc.       Amentum Holdings, Inc.
#
# ...

# %%
sp500_df_cleaned = sp500_df[['Symbol', 'Shortname']]
sp500_df_cleaned = sp500_df_cleaned.rename(columns={"Shortname": "ticker_options"})
sp500_df_cleaned.set_index(['Symbol'], inplace=True, append=False, drop=True)
sp500_df_cleaned
# Out:
#                      ticker_options
# Symbol
# AAPL                     Apple Inc.
# NVDA             NVIDIA Corporation
# MSFT          Microsoft Corporation
# AMZN               Amazon.com, Inc.
# GOOGL                 Alphabet Inc.
# ...                             ...
# CZR     Caesars Entertainment, Inc.
# BWA                 BorgWarner Inc.
# QRVO                    Qorvo, Inc.
# FMC                 FMC Corporation
# AMTM         Amentum Holdings, Inc.
#
# [502 rows x 1 columns]

# %%
sp500_json_cleaned = sp500_df_cleaned.to_json("sp500.json")
sp500_json_cleaned
